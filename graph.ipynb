# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = pd.read_csv(r'E:\data sciences\sharon\results.csv')
results
# Out:
#      epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0        1   140.360         3.19067         4.24094         4.21162
# 1        2   175.387         3.26218         4.05763         4.11279
# 2        3   208.701         3.13764         3.96837         4.02625
# 3        4   243.317         3.16419         3.95664         3.92255
# 4        5   282.879         3.06352         3.85860         3.79805
# ..     ...       ...             ...             ...             ...
# 115    116  4058.920         1.48643         2.00467         2.15584
# 116    117  4090.170         1.51801         1.94772         2.18465
# 117    118  4123.770         1.46974         1.97611         2.14740
# 118    119  4155.700         1.45367         1.91114         2.13112
# 119    120  4189.110         1.48699         1.92831         2.14308
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                 0.00277            0.72597           0.00475
# ...

# %%
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size':15})
plt.plot(results['epoch'], results['train/cls_loss'],linewidth=3,color='salmon')
plt.title('A graph of class training loss against Epochs',color='tomato')
plt.xlabel('Epochs',color='peru')
plt.grid(color='lightgray', linestyle='--', linewidth=1)
plt.ylabel("Class loss",color='yellowgreen')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.rcParams.update({'font.size': 15})

line_color = 'mediumslateblue'   
title_color = 'darkorange'       
label_color = 'teal'            
plt.plot(results['epoch'], results['train/box_loss'], linewidth=3, color=line_color)

plt.ylabel('Training Loss', color=label_color)
plt.xlabel('Epochs', color=label_color)
plt.title("Epochs against Bounding Box Loss", color=title_color)

plt.grid(color='lightgray', linestyle='--', linewidth=1)


plt.show()

# %%
results.tail()
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 115    116  4058.92         1.48643         2.00467         2.15584
# 116    117  4090.17         1.51801         1.94772         2.18465
# 117    118  4123.77         1.46974         1.97611         2.14740
# 118    119  4155.70         1.45367         1.91114         2.13112
# 119    120  4189.11         1.48699         1.92831         2.14308
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 115               0.68529            0.30412           0.38886
# 116               0.64583            0.35552           0.39562
# 117               0.65939            0.35323           0.40245
# 118               0.68017            0.35179           0.40863
# 119               0.68327            0.35485           0.41086
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 115              0.22713       1.60328       2.43931       2.28552  0.000057
# ...

# %%
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size':15})
plt.plot(results['epoch'], results['metrics/mAP50(B)'],linewidth=2)
plt.title('Precision',color='steelblue')
plt.xlabel('Epochs', color='forestgreen')
plt.ylabel('Precision',color='seagreen')
plt.grid(color='lightgray', linestyle='--', linewidth=1)
plt.show()
